# %%
import socket

sock = socket.socket( socket.AF_INET , socket.SOCK_DGRAM )

while True:
    data = input()
    sock.sendto( data.encode() , ("127.0.0.1", 9999) )
    data , addr = sock.recvfrom( 200 )
    print ( "Client send and recieved data : ", data.decode() )
    print ( "data from IP : ", addr[0] )
    print ( "data from PORT : ", addr[1] )
# Out:
# 11
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-2-d3bed72a79a6> in <module>
#       6     data = input()
#       7     sock.sendto( data.encode() , ("127.0.0.1", 9999) )
# ----> 8     data , addr = sock.recvfrom( 200 )
#       9     print ( "Client send and recieved data : ", data.decode() )
#      10     print ( "data from IP : ", addr[0] )
#
# ConnectionResetError: [WinError 10054] 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다
