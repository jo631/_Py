# %%
class node:
	def __init__(self,value=None):
		self.value=value
		self.left_child=None
		self.right_child=None
		self.parent=None # pointer to parent node in tree

class binary_search_tree:
	def __init__(self):
		self.root=None

	def insert(self,value):
		if self.root==None:
			self.root=node(value)
		else:
			self._insert(value,self.root)

	def _insert(self,value,cur_node):
		if value<cur_node.value:
			if cur_node.left_child==None:
				cur_node.left_child=node(value)
				cur_node.left_child.parent=cur_node # set parent
			else:
				self._insert(value,cur_node.left_child)
		elif value>cur_node.value:
			if cur_node.right_child==None:
				cur_node.right_child=node(value)
				cur_node.right_child.parent=cur_node # set parent
			else:
				self._insert(value,cur_node.right_child)
		#else:
			##print("Value already in tree!")

	def print_tree(self):
		if self.root!=None:
			self._print_tree(self.root)

	def _print_tree(self,cur_node):
		if cur_node!=None:
			self._print_tree(cur_node.left_child)
			print (str(cur_node.value))
			self._print_tree(cur_node.right_child)

	def height(self):
		if self.root!=None:
			return self._height(self.root,0)
		else:
			return 0

	def _height(self,cur_node,cur_height):
		if cur_node==None: return cur_height
		left_height=self._height(cur_node.left_child,cur_height+1)
		right_height=self._height(cur_node.right_child,cur_height+1)
		return max(left_height,right_height)

	def find(self,value):
		if self.root!=None:
			return self._find(value,self.root)
		else:
			return None

	def _find(self,value,cur_node):
		if value==cur_node.value:
			return cur_node
		elif value<cur_node.value and cur_node.left_child!=None:
			return self._find(value,cur_node.left_child)
		elif value>cur_node.value and cur_node.right_child!=None:
			return self._find(value,cur_node.right_child)

	def delete_value(self,value):
		return self.delete_node(self.find(value))

	def delete_node(self,node):

		## -----
		# Improvements since prior lesson

		# Protect against deleting a node not found in the tree
		if node==None or self.find(node.value)==None:
			print("Node to be deleted not found in the tree!")
			return None 
		## -----

		# returns the node with min value in tree rooted at input node
		def min_value_node(n):
			current=n
			while current.left_child!=None:
				current=current.left_child
			return current

		# returns the number of children for the specified node
		def num_children(n):
			num_children=0
			if n.left_child!=None: num_children+=1
			if n.right_child!=None: num_children+=1
			return num_children

		# get the parent of the node to be deleted
		node_parent=node.parent

		# get the number of children of the node to be deleted
		node_children=num_children(node)

		# break operation into different cases based on the
		# structure of the tree & node to be deleted

		# CASE 1 (node has no children)
		if node_children==0:

			# Added this if statement post-video, previously if you 
			# deleted the root node it would delete entire tree.
			if node_parent!=None:
				# remove reference to the node from the parent
				if node_parent.left_child==node:
					node_parent.left_child=None
				else:
					node_parent.right_child=None
			else:
				self.root=None

		# CASE 2 (node has a single child)
		if node_children==1:

			# get the single child node
			if node.left_child!=None:
				child=node.left_child
			else:
				child=node.right_child

			# Added this if statement post-video, previously if you 
			# deleted the root node it would delete entire tree.
			if node_parent!=None:
				# replace the node to be deleted with its child
				if node_parent.left_child==node:
					node_parent.left_child=child
				else:
					node_parent.right_child=child
			else:
				self.root=child

			# correct the parent pointer in node
			child.parent=node_parent

		# CASE 3 (node has two children)
		if node_children==2:

			# get the inorder successor of the deleted node
			successor=min_value_node(node.right_child)

			# copy the inorder successor's value to the node formerly
			# holding the value we wished to delete
			node.value=successor.value

			# delete the inorder successor now that it's value was
			# copied into the other node
			self.delete_node(successor)

	def search(self,value):
		if self.root!=None:
			return self._search(value,self.root)
		else:
			return False

	def _search(self,value,cur_node):
		if value==cur_node.value:
			return True
		elif value<cur_node.value and cur_node.left_child!=None:
			return self._search(value,cur_node.left_child)
		elif value>cur_node.value and cur_node.right_child!=None:
			return self._search(value,cur_node.right_child)
		return False

# %%
import time
import numpy as np

NUM = 1000

for i in range(10):
    t = binary_search_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.insert(num)
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.height())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.delete_value(randNum)
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  0.005984306335449219
# 1 번째 트리 높이:  19
# 1 - 1 번째 탐색, 찾는 숫자 7431752 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 4666120 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 3928095 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 1818495 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 394677 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  0.003989696502685547
# 2 번째 트리 높이:  20
# 2 - 1 번째 탐색, 찾는 숫자 1456997 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 5736368 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 562736 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 1623268 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 3819147 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  0.004978179931640625
# 3 번째 트리 높이:  20
# 3 - 1 번째 탐색, 찾는 숫자 3418039 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 6093025 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 2211348 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 7072295 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 1055822 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  0.002991914749145508
# 4 번째 트리 높이:  24
# 4 - 1 번째 탐색, 찾는 숫자 6963168 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 3940199 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 2225540 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 7492883 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 4761342 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  0.006985902786254883
# 5 번째 트리 높이:  27
# 5 - 1 번째 탐색, 찾는 숫자 1430760 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 5216746 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 2132838 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 4295371 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 1235403 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  0.002991199493408203
# 6 번째 트리 높이:  22
# 6 - 1 번째 탐색, 찾는 숫자 8720974 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 280194 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 170701 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 8866088 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 5956340 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  0.004985809326171875
# 7 번째 트리 높이:  21
# 7 - 1 번째 탐색, 찾는 숫자 9953313 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 1260127 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 7727148 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 2868261 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 278518 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  0.0039882659912109375
# 8 번째 트리 높이:  22
# 8 - 1 번째 탐색, 찾는 숫자 2722138 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 7998265 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 6586974 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 225636 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 8763155 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  0.0049860477447509766
# 9 번째 트리 높이:  26
# 9 - 1 번째 탐색, 찾는 숫자 9450524 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 5411528 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 5141690 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 282235 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 5753033 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  0.003991842269897461
# 10 번째 트리 높이:  21
# 10 - 1 번째 탐색, 찾는 숫자 1090541 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 354559 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 6069251 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 9473921 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 319159 탐색+삭제 시간: 0.0

# %%
import time
import numpy as np

NUM = 10000

for i in range(10):
    t = binary_search_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.insert(num)
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.height())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.delete_value(randNum)
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  0.07383275032043457
# 1 번째 트리 높이:  31
# 1 - 1 번째 탐색, 찾는 숫자 4956688 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 4491766 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 414756 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 4079595 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 1676693 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  0.10771012306213379
# 2 번째 트리 높이:  29
# 2 - 1 번째 탐색, 찾는 숫자 2873641 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 4020575 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 2130626 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 7767525 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 2454500 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  0.058829545974731445
# 3 번째 트리 높이:  28
# 3 - 1 번째 탐색, 찾는 숫자 214279 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 3466761 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 630061 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 822990 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 3235682 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  0.06716513633728027
# 4 번째 트리 높이:  30
# 4 - 1 번째 탐색, 찾는 숫자 5928591 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 1382540 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 1981348 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 9270563 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 1257843 탐색+삭제 시간: 0.0009982585906982422
#
# 5 번째 트리 생성 시간:  0.0747995376586914
# 5 번째 트리 높이:  34
# 5 - 1 번째 탐색, 찾는 숫자 3692652 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 114474 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 9535051 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 8896488 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 7183664 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  0.057845354080200195
# 6 번째 트리 높이:  32
# 6 - 1 번째 탐색, 찾는 숫자 7211254 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 4707049 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 4684317 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 257427 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 5385305 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  0.1125648021697998
# 7 번째 트리 높이:  35
# 7 - 1 번째 탐색, 찾는 숫자 677743 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 5028846 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 6306878 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 5161683 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 5597885 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  0.0528562068939209
# 8 번째 트리 높이:  29
# 8 - 1 번째 탐색, 찾는 숫자 3443517 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 4247083 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 4403050 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 2753081 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 6206922 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  0.06582260131835938
# 9 번째 트리 높이:  32
# 9 - 1 번째 탐색, 찾는 숫자 3936842 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 9248876 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 988022 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 6250126 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 9660831 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  0.05884122848510742
# 10 번째 트리 높이:  29
# 10 - 1 번째 탐색, 찾는 숫자 2914958 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 6578364 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 2209927 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 1955096 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 2270779 탐색+삭제 시간: 0.0

# %%
import time
import numpy as np


NUM = 100000
timeSum = []
heightSum = []
for i in range(10):
    t = binary_search_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.insert(num)
    timeSum.append(time.time() - start)
    heightSum.append(t.height())
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.height())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.delete_value(randNum)
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()


print(np.mean(timeSum))
print(np.mean(heightSum))
# Out:
# 1 번째 트리 생성 시간:  2.6376733779907227
# 1 번째 트리 높이:  44
# 1 - 1 번째 탐색, 찾는 숫자 8715432 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 8076607 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 3728503 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 7238464 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 7341089 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  1.0030176639556885
# 2 번째 트리 높이:  44
# 2 - 1 번째 탐색, 찾는 숫자 8707809 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 1145187 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 5703798 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 2311977 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 8916626 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  0.9826045036315918
# 3 번째 트리 높이:  40
# 3 - 1 번째 탐색, 찾는 숫자 4111658 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 9654463 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 3264673 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 5551378 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 294924 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  0.9505670070648193
# 4 번째 트리 높이:  48
# 4 - 1 번째 탐색, 찾는 숫자 8065880 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 4607059 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 6946294 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 4056225 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 4372716 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  1.0790412425994873
# 5 번째 트리 높이:  42
# 5 - 1 번째 탐색, 찾는 숫자 7309099 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 9571624 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 5365277 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 6681364 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 5537542 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  0.9006180763244629
# 6 번째 트리 높이:  41
# 6 - 1 번째 탐색, 찾는 숫자 3088977 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 6832505 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 2347622 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 8444189 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 4366021 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  0.9731221199035645
# 7 번째 트리 높이:  39
# 7 - 1 번째 탐색, 찾는 숫자 2490875 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 2701516 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 9049238 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 1946731 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 729055 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  1.2363991737365723
# 8 번째 트리 높이:  40
# 8 - 1 번째 탐색, 찾는 숫자 8077982 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 6720833 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 476867 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 7123401 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 9983934 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  1.1232078075408936
# 9 번째 트리 높이:  38
# 9 - 1 번째 탐색, 찾는 숫자 2498426 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 1247803 탐색+삭제 시간: 0.0009629726409912109
# 9 - 3 번째 탐색, 찾는 숫자 3145236 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 1811175 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 3233496 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  1.1096258163452148
# 10 번째 트리 높이:  38
# 10 - 1 번째 탐색, 찾는 숫자 9289664 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 6594824 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 4690372 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 3445383 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 5040772 탐색+삭제 시간: 0.0
#
# 1.1217306137084961
# 41.4

# %%
import time
import numpy as np

NUM = 1000000
timeSum = []
heightSum = []

for i in range(10):
    t = binary_search_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.insert(num)
    timeSum.append(time.time() - start)
    heightSum.append(t.height())
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.height())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.delete_value(randNum)
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
    

print(np.mean(timeSum))
print(np.mean(heightSum))
# Out:
# nan
# nan
# 1 번째 트리 생성 시간:  17.704874277114868
# 1 번째 트리 높이:  55
# 1 - 1 번째 탐색, 찾는 숫자 9677558 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 3266211 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 3793027 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 5870278 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 3243118 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  17.447664260864258
# 2 번째 트리 높이:  47
# 2 - 1 번째 탐색, 찾는 숫자 2694336 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 2015008 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 8902071 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 2107447 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 9292115 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  15.824125051498413
# 3 번째 트리 높이:  48
# 3 - 1 번째 탐색, 찾는 숫자 5540230 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 8049454 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 686967 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 6982358 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 6115005 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  19.49443221092224
# 4 번째 트리 높이:  48
# 4 - 1 번째 탐색, 찾는 숫자 6369822 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 1494805 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 6951919 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 6387744 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 3068088 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  17.58405876159668
# 5 번째 트리 높이:  49
# 5 - 1 번째 탐색, 찾는 숫자 6145137 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 2531666 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 4019596 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 470149 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 9294063 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  19.617541551589966
# 6 번째 트리 높이:  49
# 6 - 1 번째 탐색, 찾는 숫자 1757671 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 6421171 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 4906314 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 273123 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 8999148 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  21.354477167129517
# 7 번째 트리 높이:  52
# 7 - 1 번째 탐색, 찾는 숫자 8504515 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 6240739 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 2688706 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 4208726 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 3038168 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  15.683081865310669
# 8 번째 트리 높이:  49
# 8 - 1 번째 탐색, 찾는 숫자 1307102 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 8862064 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 668095 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 4327440 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 2360001 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  17.89881944656372
# 9 번째 트리 높이:  53
# 9 - 1 번째 탐색, 찾는 숫자 4025296 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 1694365 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 2703241 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 7700245 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 7870458 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  17.720387935638428
# 10 번째 트리 높이:  52
# 10 - 1 번째 탐색, 찾는 숫자 8512063 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 5960382 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 213119 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 683038 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 3343171 탐색+삭제 시간: 0.0
#
# 17.24200232028961
# 50.2
