# %%
class Node:

    def __init__(self, newval): 
        self.key = newval
        self.left = None
        self.right = None
        self.parent = None
        self.color = "black"


# In[6]:

class rb_tree:

	def __init__(self):
		self.nil = Node(None)
		self.root = self.nil
    
	def getRoot(self):
		return self.root
    
	def left_rotate(self, x):
		y = x.right
		x.right = y.left
		if y.left != self.nil:
			y.left.parent = x	
		y.parent = x.parent
		if x.parent == self.nil:
			self.root = y
		elif x == x.parent.left :
			x.parent.left = y
		else:
			x.parent.right = y
		y.left = x
		x.parent = y 

	def get_root(self):
		return self.root

        

	def right_rotate(self, x):
		y = x.left  
		x.left = y.right 
		if y.right != self.nil:
			y.right.parent = x
		y.parent = x.parent
		if x.parent == self.nil:
			self.root = y
		elif x == x.parent.left:
			x.parent.left = y
		else:
			x.parent.right = y
		y.right = x
		x.parent = y


	def rb_insert(self, z):
		y = self.nil
		x = self.root
		while x is not self.nil:
			y = x
			if z.key < x.key:
				x = x.left
			else:
				x = x.right
		z.parent = y
		if y == self.nil:
			self.root = z
		elif z.key < y.key:
			y.left = z
		else:
			y.right = z
		z.left = self.nil
		z.right = self.nil
		z.color = "red"
		self.rb_insert_fixup(z)


	def rb_insert_fixup(self, z):
		while z.parent.color == "red":
			if z.parent == z.parent.parent.left:
				y = z.parent.parent.right
				if y.color == "red":
					z.parent.color = "black"
					y.color = "black"
					z.parent.parent.color = "red"
					z = z.parent.parent
				elif z == z.parent.right:
					z = z.parent
					self.left_rotate(z)
				else:
					z.parent.color = "black"
					z.parent.parent.color = "red"
					self.right_rotate(z.parent.parent)
			else:
				y = z.parent.parent.left
				if y.color == "red":
					z.parent.color = "black"
					y.color = "black"
					z.parent.parent.color = "red"
					z = z.parent.parent
				elif z == z.parent.left:
					z = z.parent
					self.right_rotate(z)
				else:
					z.parent.color = "black"
					z.parent.parent.color = "red"
					self.left_rotate(z.parent.parent)
		self.root.color = "black"

	def rb_min(self, tree):
		while tree.left.key != None:  
			tree = tree.left
		return tree

	def rb_max(self, tree):
		while tree.right.key != None:
			tree = tree.right
		return tree


	def rb_transplant(self, u, v):
		if u.parent == self.nil:
			self.root = v
		elif u == u.parent.left:
			u.parent.left = v
		else:
			u.parent.right = v
		v.parent = u.parent


	def rb_delete(self, z):
		y = z
		y_original_color = y.color
		if z.left == self.nil:
			x = z.right
			self.rb_transplant(z, z.right)
		elif z.right == self.nil:
			x = z.left
			self.rb_transplant(z, z.left)
		else:
			y = self.rb_min(z.right) 
			y_original_color = y.color
			x = y.right
			if y.parent == z:
				x.parent = y
			else:
				self.rb_transplant(y, y.right)
				y.right = z.right
				y.right.parent = y
			self.rb_transplant(z, y)
			y.left = z.left
			y.left.parent = y
			y.color = z.color
		if y_original_color == "black":
			self.rb_delete_fixup(x)

	def rb_delete_fixup(self, x):
		while x != self.root and x.color == "black":
			if x == x.parent.left:
				w = x.parent.right
				if w.color == "red":
					w.color = "black"
					x.parent.color = "red"
					self.left_rotate(x.parent)
					w = x.parent.right
				if w.left.color == "black" and w.right.color == "black":
					w.color = "red"
					x = x.parent
				else:
					if w.right.color == "black":
						w.left.color = "black"
						w.color = "red"
						self.right_rotate(w)
						w = x.parent.right
					w.color = x.parent.color
					x.parent.color = "black"
					w.right.color = "black"
					self.left_rotate(x.parent)
					x = self.root
			else:
				w = x.parent.left
				if w.color == "red":
					w.color = "black"
					x.parent.color = "red"
					self.right_rotate(x.parent)
					w = x.parent.left
				if w.right.color == "black" and w.left.color == "black":
					w.color = "red"
					x = x.parent
				else:
					if w.left.color == "black":
						w.right.color == "black"
						w.color = "red"
						self.left_rotate(w)
						w = x.parent.left		
					w.color = x.parent.color
					x.parent.color = "black"
					w.left.color = "black"
					self.right_rotate(x.parent)
					x = self.root
		x.color = "black"



	def search(self, tree, k):
		if tree.key == None or k == tree.key:
			return tree
		if k < tree.key:
			return self.search(tree.left, k)
		else:
			return self.search(tree.right, k)



	inorder_result = [ ]
	blacknode = [ ]

	def inorder(self,tree):
		if tree is None:
			return
		else:
			self.inorder(tree.left)
			if tree.color is "black":
				rb_tree.blacknode.append(tree.key)
			rb_tree.inorder_result.append(tree.key)
			self.inorder(tree.right)
		

	def print(self,tree,level):
	    if tree.right is not None:
	        self.print(tree.right,level + 1)
	    for i in range(level):
	        print('   	', end='')
	    print((tree.key, tree.color))
	    if tree.left is not None:
	        self.print(tree.left, level + 1)

	def rb_bh(self):
		x = self.root
		bh = 0
		while x is not self.nil:
			if x.color is "black":
				bh = bh + 1
			x = x.right
		return bh

# %%
import time
import numpy as np

t = rb_tree()

NUM = 1000

for i in range(10):
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  0.011946678161621094
# 1 번째 트리 높이:  6
# 1 - 1 번째 탐색, 찾는 숫자 63441 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 19166 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 26951 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 61414 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 54634 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  0.005982875823974609
# 2 번째 트리 높이:  7
# 2 - 1 번째 탐색, 찾는 숫자 32971 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 74230 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 14521 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 60898 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 52123 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  0.004031658172607422
# 3 번째 트리 높이:  7
# 3 - 1 번째 탐색, 찾는 숫자 68065 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 23708 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 17938 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 68385 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 90711 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  0.0039882659912109375
# 4 번째 트리 높이:  8
# 4 - 1 번째 탐색, 찾는 숫자 73563 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 96839 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 17096 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 20864 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 87413 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  0.004029273986816406
# 5 번째 트리 높이:  8
# 5 - 1 번째 탐색, 찾는 숫자 39829 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 64198 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 16342 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 41661 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 94980 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  0.004033088684082031
# 6 번째 트리 높이:  8
# 6 - 1 번째 탐색, 찾는 숫자 87129 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 40735 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 40246 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 74747 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 1090 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  0.0039997100830078125
# 7 번째 트리 높이:  8
# 7 - 1 번째 탐색, 찾는 숫자 59544 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 40693 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 32659 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 10245 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 42135 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  0.002408266067504883
# 8 번째 트리 높이:  8
# 8 - 1 번째 탐색, 찾는 숫자 48188 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 15963 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 39541 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 25653 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 40806 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  0.0
# 9 번째 트리 높이:  8
# 9 - 1 번째 탐색, 찾는 숫자 99816 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 46672 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 6507 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 7262 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 14359 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  0.04689431190490723
# 10 번째 트리 높이:  8
# 10 - 1 번째 탐색, 찾는 숫자 7378 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 22063 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 58145 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 67379 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 66452 탐색+삭제 시간: 0.0

# %%
import time
import numpy as np

t = rb_tree()

NUM = 10000

for i in range(10):
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  0.04890561103820801
# 1 번째 트리 높이:  8
# 1 - 1 번째 탐색, 찾는 숫자 21038 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 47188 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 37187 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 84585 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 86084 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  0.033330678939819336
# 2 번째 트리 높이:  9
# 2 - 1 번째 탐색, 찾는 숫자 5066 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 20117 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 8799 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 32990 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 19930 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  0.04432249069213867
# 3 번째 트리 높이:  9
# 3 - 1 번째 탐색, 찾는 숫자 48107 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 38032 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 56242 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 27883 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 14257 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  0.06247687339782715
# 4 번째 트리 높이:  10
# 4 - 1 번째 탐색, 찾는 숫자 42238 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 89478 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 44632 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 27584 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 87720 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  0.1286606788635254
# 5 번째 트리 높이:  10
# 5 - 1 번째 탐색, 찾는 숫자 33303 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 71911 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 99044 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 32466 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 74789 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  0.06786084175109863
# 6 번째 트리 높이:  10
# 6 - 1 번째 탐색, 찾는 숫자 74771 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 32199 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 30894 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 33008 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 24639 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  0.08477997779846191
# 7 번째 트리 높이:  10
# 7 - 1 번째 탐색, 찾는 숫자 48283 탐색+삭제 시간: 0.0009481906890869141
# 7 - 2 번째 탐색, 찾는 숫자 48420 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 87602 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 69897 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 78354 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  0.0758063793182373
# 8 번째 트리 높이:  10
# 8 - 1 번째 탐색, 찾는 숫자 40171 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 60711 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 51475 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 60004 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 1103 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  0.05394554138183594
# 9 번째 트리 높이:  10
# 9 - 1 번째 탐색, 찾는 숫자 63462 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 49074 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 12292 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 72718 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 32751 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  0.18225812911987305
# 10 번째 트리 높이:  11
# 10 - 1 번째 탐색, 찾는 숫자 62253 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 28778 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 92447 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 57534 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 23329 탐색+삭제 시간: 0.0

# %%
import time
import numpy as np

t = rb_tree()

NUM = 100000

for i in range(10):
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  0.956899881362915
# 1 번째 트리 높이:  11
# 1 - 1 번째 탐색, 찾는 숫자 75381 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 87479 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 61297 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 7745 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 40458 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  1.2141356468200684
# 2 번째 트리 높이:  11
# 2 - 1 번째 탐색, 찾는 숫자 98521 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 22375 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 28893 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 22213 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 98306 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  1.1514194011688232
# 3 번째 트리 높이:  11
# 3 - 1 번째 탐색, 찾는 숫자 38800 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 50933 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 43607 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 74878 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 43915 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  1.8972804546356201
# 4 번째 트리 높이:  12
# 4 - 1 번째 탐색, 찾는 숫자 88918 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 63282 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 9459 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 34361 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 60631 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  1.0277457237243652
# 5 번째 트리 높이:  12
# 5 - 1 번째 탐색, 찾는 숫자 91682 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 21510 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 97427 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 35618 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 45603 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  1.8119778633117676
# 6 번째 트리 높이:  12
# 6 - 1 번째 탐색, 찾는 숫자 14117 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 91877 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 75991 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 30212 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 40614 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  2.0711350440979004
# 7 번째 트리 높이:  12
# 7 - 1 번째 탐색, 찾는 숫자 8357 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 44966 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 55464 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 41261 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 94063 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  1.0147438049316406
# 8 번째 트리 높이:  12
# 8 - 1 번째 탐색, 찾는 숫자 43277 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 6203 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 36907 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 44244 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 28808 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  2.415008068084717
# 9 번째 트리 높이:  13
# 9 - 1 번째 탐색, 찾는 숫자 44051 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 90421 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 55288 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 12891 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 38855 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  1.0917398929595947
# 10 번째 트리 높이:  13
# 10 - 1 번째 탐색, 찾는 숫자 71452 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 94416 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 93356 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 99618 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 66409 탐색+삭제 시간: 0.0

# %%
import time
import numpy as np

t = rb_tree()

NUM = 1000000

for i in range(10):
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  19.01984715461731
# 1 번째 트리 높이:  13
# 1 - 1 번째 탐색, 찾는 숫자 47079 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 2636 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 21711 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 14606 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 25634 탐색+삭제 시간: 0.0
