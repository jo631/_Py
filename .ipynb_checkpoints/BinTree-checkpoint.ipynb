# %%
from bintrees import BinaryTree
from bintrees import AVLTree
from bintrees import *

# %%
t = AVLTree()

# %%
t.clear()
t.insert(5,5)
t.insert(6,6)
t.insert(9,9)
t.insert(8,8)
t.insert(10,10)
t.insert(7,7)
t.insert(4,4)
t.insert(1,1)
t.insert(3,3)
t.insert(2,2)
t.count
# Out:
# 10

# %%
# Out:
# bintrees.abctree.CPYTHON_ABCTree

# %%
t.floor_item(1)
# Out:
# (1, 1)
