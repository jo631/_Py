# %%
from bintrees import BinaryTree
from bintrees import AVLTree
from bintrees import RBTree

# %%
t = AVLTree()

# %%
t.insert(3,3)
t.insert(1,1)
t.insert(2,2)

# %%
t.
# Out:
# <generator object _ABCTree.values.<locals>.<genexpr> at 0x00000209A21036D0>
