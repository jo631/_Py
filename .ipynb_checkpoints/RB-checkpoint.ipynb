# %%
class Node:

    def __init__(self, newval): 
        self.key = newval
        self.left = None
        self.right = None
        self.parent = None
        self.color = "black"


# In[6]:

class rb_tree:

	def __init__(self):
		self.nil = Node(None)
		self.root = self.nil
    
	def getRoot(self):
		return self.root
    
	def left_rotate(self, x):
		y = x.right
		x.right = y.left
		if y.left != self.nil:
			y.left.parent = x	
		y.parent = x.parent
		if x.parent == self.nil:
			self.root = y
		elif x == x.parent.left :
			x.parent.left = y
		else:
			x.parent.right = y
		y.left = x
		x.parent = y 

	def get_root(self):
		return self.root

        

	def right_rotate(self, x):
		y = x.left  
		x.left = y.right 
		if y.right != self.nil:
			y.right.parent = x
		y.parent = x.parent
		if x.parent == self.nil:
			self.root = y
		elif x == x.parent.left:
			x.parent.left = y
		else:
			x.parent.right = y
		y.right = x
		x.parent = y


	def rb_insert(self, z):
		y = self.nil
		x = self.root
		while x is not self.nil:
			y = x
			if z.key < x.key:
				x = x.left
			else:
				x = x.right
		z.parent = y
		if y == self.nil:
			self.root = z
		elif z.key < y.key:
			y.left = z
		else:
			y.right = z
		z.left = self.nil
		z.right = self.nil
		z.color = "red"
		self.rb_insert_fixup(z)


	def rb_insert_fixup(self, z):
		while z.parent.color == "red":
			if z.parent == z.parent.parent.left:
				y = z.parent.parent.right
				if y.color == "red":
					z.parent.color = "black"
					y.color = "black"
					z.parent.parent.color = "red"
					z = z.parent.parent
				elif z == z.parent.right:
					z = z.parent
					self.left_rotate(z)
				else:
					z.parent.color = "black"
					z.parent.parent.color = "red"
					self.right_rotate(z.parent.parent)
			else:
				y = z.parent.parent.left
				if y.color == "red":
					z.parent.color = "black"
					y.color = "black"
					z.parent.parent.color = "red"
					z = z.parent.parent
				elif z == z.parent.left:
					z = z.parent
					self.right_rotate(z)
				else:
					z.parent.color = "black"
					z.parent.parent.color = "red"
					self.left_rotate(z.parent.parent)
		self.root.color = "black"

	def rb_min(self, tree):
		while tree.left.key != None:  
			tree = tree.left
		return tree

	def rb_max(self, tree):
		while tree.right.key != None:
			tree = tree.right
		return tree


	def rb_transplant(self, u, v):
		if u.parent == self.nil:
			self.root = v
		elif u == u.parent.left:
			u.parent.left = v
		else:
			u.parent.right = v
		v.parent = u.parent


	def rb_delete(self, z):
		y = z
		y_original_color = y.color
		if z.left == self.nil:
			x = z.right
			self.rb_transplant(z, z.right)
		elif z.right == self.nil:
			x = z.left
			self.rb_transplant(z, z.left)
		else:
			y = self.rb_min(z.right) 
			y_original_color = y.color
			x = y.right
			if y.parent == z:
				x.parent = y
			else:
				self.rb_transplant(y, y.right)
				y.right = z.right
				y.right.parent = y
			self.rb_transplant(z, y)
			y.left = z.left
			y.left.parent = y
			y.color = z.color
		if y_original_color == "black":
			self.rb_delete_fixup(x)

	def rb_delete_fixup(self, x):
		while x != self.root and x.color == "black":
			if x == x.parent.left:
				w = x.parent.right
				if w.color == "red":
					w.color = "black"
					x.parent.color = "red"
					self.left_rotate(x.parent)
					w = x.parent.right
				if w.left.color == "black" and w.right.color == "black":
					w.color = "red"
					x = x.parent
				else:
					if w.right.color == "black":
						w.left.color = "black"
						w.color = "red"
						self.right_rotate(w)
						w = x.parent.right
					w.color = x.parent.color
					x.parent.color = "black"
					w.right.color = "black"
					self.left_rotate(x.parent)
					x = self.root
			else:
				w = x.parent.left
				if w.color == "red":
					w.color = "black"
					x.parent.color = "red"
					self.right_rotate(x.parent)
					w = x.parent.left
				if w.right.color == "black" and w.left.color == "black":
					w.color = "red"
					x = x.parent
				else:
					if w.left.color == "black":
						w.right.color == "black"
						w.color = "red"
						self.left_rotate(w)
						w = x.parent.left		
					w.color = x.parent.color
					x.parent.color = "black"
					w.left.color = "black"
					self.right_rotate(x.parent)
					x = self.root
		x.color = "black"



	def search(self, tree, k):
		if tree.key == None or k == tree.key:
			return tree
		if k < tree.key:
			return self.search(tree.left, k)
		else:
			return self.search(tree.right, k)



	inorder_result = [ ]
	blacknode = [ ]

	def inorder(self,tree):
		if tree is None:
			return
		else:
			self.inorder(tree.left)
			if tree.color is "black":
				rb_tree.blacknode.append(tree.key)
			rb_tree.inorder_result.append(tree.key)
			self.inorder(tree.right)
		

	def print(self,tree,level):
	    if tree.right is not None:
	        self.print(tree.right,level + 1)
	    for i in range(level):
	        print('   	', end='')
	    print((tree.key, tree.color))
	    if tree.left is not None:
	        self.print(tree.left, level + 1)

	def rb_bh(self):
		x = self.root
		bh = 0
		while x is not self.nil:
			if x.color is "black":
				bh = bh + 1
			x = x.right
		return bh

# %%
import time
import numpy as np

NUM = 1000

for i in range(10):
    t = rb_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  0.00498652458190918
# 1 번째 트리 높이:  6
# 1 - 1 번째 탐색, 찾는 숫자 7612 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 30672 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 88337 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 90558 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 92300 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  0.00398707389831543
# 2 번째 트리 높이:  7
# 2 - 1 번째 탐색, 찾는 숫자 19217 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 37162 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 11644 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 721 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 86899 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  0.003028392791748047
# 3 번째 트리 높이:  6
# 3 - 1 번째 탐색, 찾는 숫자 50759 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 46550 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 24957 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 51494 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 95997 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  0.004030466079711914
# 4 번째 트리 높이:  6
# 4 - 1 번째 탐색, 찾는 숫자 34439 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 34488 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 15016 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 47324 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 78918 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  0.005014657974243164
# 5 번째 트리 높이:  7
# 5 - 1 번째 탐색, 찾는 숫자 12796 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 41730 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 76446 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 24642 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 29342 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  0.0030362606048583984
# 6 번째 트리 높이:  7
# 6 - 1 번째 탐색, 찾는 숫자 274 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 62066 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 89414 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 9755 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 22436 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  0.0030405521392822266
# 7 번째 트리 높이:  6
# 7 - 1 번째 탐색, 찾는 숫자 18167 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 10915 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 85179 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 6440 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 77425 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  0.0040340423583984375
# 8 번째 트리 높이:  6
# 8 - 1 번째 탐색, 찾는 숫자 65215 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 59557 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 21895 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 15226 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 54793 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  0.003046751022338867
# 9 번째 트리 높이:  6
# 9 - 1 번째 탐색, 찾는 숫자 95605 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 34263 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 22127 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 2114 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 387 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  0.003989696502685547
# 10 번째 트리 높이:  6
# 10 - 1 번째 탐색, 찾는 숫자 16189 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 11316 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 53598 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 26151 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 42731 탐색+삭제 시간: 0.0

# %%
import time
import numpy as np

NUM = 10000

for i in range(10):
    t = rb_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  0.06532716751098633
# 1 번째 트리 높이:  8
# 1 - 1 번째 탐색, 찾는 숫자 80606 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 80096 탐색+삭제 시간: 0.0009965896606445312
# 1 - 3 번째 탐색, 찾는 숫자 68074 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 58583 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 64131 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  0.035653114318847656
# 2 번째 트리 높이:  8
# 2 - 1 번째 탐색, 찾는 숫자 69594 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 1848 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 38081 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 67134 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 89288 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  0.03123164176940918
# 3 번째 트리 높이:  8
# 3 - 1 번째 탐색, 찾는 숫자 1558 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 75085 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 92249 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 1733 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 3306 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  0.03126382827758789
# 4 번째 트리 높이:  8
# 4 - 1 번째 탐색, 찾는 숫자 70944 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 94711 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 80735 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 28249 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 54500 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  0.03377413749694824
# 5 번째 트리 높이:  8
# 5 - 1 번째 탐색, 찾는 숫자 22933 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 81514 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 82393 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 19756 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 14616 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  0.03262662887573242
# 6 번째 트리 높이:  8
# 6 - 1 번째 탐색, 찾는 숫자 57799 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 96429 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 83331 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 613 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 84516 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  0.03400397300720215
# 7 번째 트리 높이:  8
# 7 - 1 번째 탐색, 찾는 숫자 15918 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 39857 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 99255 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 20854 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 10409 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  0.031237363815307617
# 8 번째 트리 높이:  8
# 8 - 1 번째 탐색, 찾는 숫자 24318 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 53102 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 87994 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 81716 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 70302 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  0.046865224838256836
# 9 번째 트리 높이:  8
# 9 - 1 번째 탐색, 찾는 숫자 84465 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 50264 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 59697 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 109 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 2449 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  0.059037208557128906
# 10 번째 트리 높이:  8
# 10 - 1 번째 탐색, 찾는 숫자 76722 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 2828 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 75968 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 89509 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 37408 탐색+삭제 시간: 0.0

# %%
import time
import numpy as np


NUM = 100000

for i in range(10):
    t = rb_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  0.5732631683349609
# 1 번째 트리 높이:  11
# 1 - 1 번째 탐색, 찾는 숫자 3624 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 7272 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 65305 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 2060 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 72371 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  0.6207897663116455
# 2 번째 트리 높이:  10
# 2 - 1 번째 탐색, 찾는 숫자 37136 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 43006 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 45535 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 78159 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 6772 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  0.5834565162658691
# 3 번째 트리 높이:  10
# 3 - 1 번째 탐색, 찾는 숫자 49729 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 37436 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 16895 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 7157 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 85587 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  0.5849692821502686
# 4 번째 트리 높이:  11
# 4 - 1 번째 탐색, 찾는 숫자 3425 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 55271 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 23983 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 95470 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 69792 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  0.6831552982330322
# 5 번째 트리 높이:  10
# 5 - 1 번째 탐색, 찾는 숫자 22938 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 66505 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 15784 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 31343 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 91815 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  0.7160470485687256
# 6 번째 트리 높이:  11
# 6 - 1 번째 탐색, 찾는 숫자 45649 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 56802 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 73799 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 39957 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 59355 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  0.7034163475036621
# 7 번째 트리 높이:  10
# 7 - 1 번째 탐색, 찾는 숫자 15148 탐색+삭제 시간: 0.0009975433349609375
# 7 - 2 번째 탐색, 찾는 숫자 81242 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 68500 탐색+삭제 시간: 0.0010132789611816406
# 7 - 4 번째 탐색, 찾는 숫자 86706 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 52850 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  0.7133119106292725
# 8 번째 트리 높이:  10
# 8 - 1 번째 탐색, 찾는 숫자 13395 탐색+삭제 시간: 0.0009655952453613281
# 8 - 2 번째 탐색, 찾는 숫자 32408 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 50593 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 98320 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 94340 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  0.5963430404663086
# 9 번째 트리 높이:  10
# 9 - 1 번째 탐색, 찾는 숫자 79133 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 77454 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 66422 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 69763 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 55555 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  0.5983474254608154
# 10 번째 트리 높이:  10
# 10 - 1 번째 탐색, 찾는 숫자 32600 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 81069 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 79881 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 78656 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 97211 탐색+삭제 시간: 0.0

# %%
import time
import numpy as np

NUM = 1000000

for i in range(10):
    t = rb_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  15.448350429534912
# 1 번째 트리 높이:  13
# 1 - 1 번째 탐색, 찾는 숫자 76021 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 49544 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 8619 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 26528 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 26495 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  18.240063428878784
# 2 번째 트리 높이:  13
# 2 - 1 번째 탐색, 찾는 숫자 49123 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 1188 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 11495 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 79862 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 67444 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  17.562023162841797
# 3 번째 트리 높이:  13
# 3 - 1 번째 탐색, 찾는 숫자 38154 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 33273 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 86752 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 75033 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 54404 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  17.310981512069702
# 4 번째 트리 높이:  12
# 4 - 1 번째 탐색, 찾는 숫자 62018 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 87965 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 63239 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 1142 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 68702 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  17.3884756565094
# 5 번째 트리 높이:  13
# 5 - 1 번째 탐색, 찾는 숫자 12135 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 29273 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 24060 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 87579 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 39580 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  19.02377963066101
# 6 번째 트리 높이:  13
# 6 - 1 번째 탐색, 찾는 숫자 28432 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 91101 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 29248 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 54725 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 34331 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  17.77713131904602
# 7 번째 트리 높이:  13
# 7 - 1 번째 탐색, 찾는 숫자 83886 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 99783 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 56796 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 13034 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 54794 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  18.59088969230652
# 8 번째 트리 높이:  13
# 8 - 1 번째 탐색, 찾는 숫자 86703 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 57097 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 83852 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 18783 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 33391 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  17.297511100769043
# 9 번째 트리 높이:  13
# 9 - 1 번째 탐색, 찾는 숫자 92569 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 30233 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 25364 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 76830 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 66168 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  18.955934762954712
# 10 번째 트리 높이:  13
# 10 - 1 번째 탐색, 찾는 숫자 35331 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 75372 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 30450 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 10823 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 76901 탐색+삭제 시간: 0.0
