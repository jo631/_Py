# %%
class Node:

    def __init__(self, newval): 
        self.key = newval
        self.left = None
        self.right = None
        self.parent = None
        self.color = "black"


# In[6]:

class rb_tree:

	def __init__(self):
		self.nil = Node(None)
		self.root = self.nil
    
	def getRoot(self):
		return self.root
    
	def left_rotate(self, x):
		y = x.right
		x.right = y.left
		if y.left != self.nil:
			y.left.parent = x	
		y.parent = x.parent
		if x.parent == self.nil:
			self.root = y
		elif x == x.parent.left :
			x.parent.left = y
		else:
			x.parent.right = y
		y.left = x
		x.parent = y 

	def get_root(self):
		return self.root

        

	def right_rotate(self, x):
		y = x.left  
		x.left = y.right 
		if y.right != self.nil:
			y.right.parent = x
		y.parent = x.parent
		if x.parent == self.nil:
			self.root = y
		elif x == x.parent.left:
			x.parent.left = y
		else:
			x.parent.right = y
		y.right = x
		x.parent = y


	def rb_insert(self, z):
		y = self.nil
		x = self.root
		while x is not self.nil:
			y = x
			if z.key < x.key:
				x = x.left
			else:
				x = x.right
		z.parent = y
		if y == self.nil:
			self.root = z
		elif z.key < y.key:
			y.left = z
		else:
			y.right = z
		z.left = self.nil
		z.right = self.nil
		z.color = "red"
		self.rb_insert_fixup(z)


	def rb_insert_fixup(self, z):
		while z.parent.color == "red":
			if z.parent == z.parent.parent.left:
				y = z.parent.parent.right
				if y.color == "red":
					z.parent.color = "black"
					y.color = "black"
					z.parent.parent.color = "red"
					z = z.parent.parent
				elif z == z.parent.right:
					z = z.parent
					self.left_rotate(z)
				else:
					z.parent.color = "black"
					z.parent.parent.color = "red"
					self.right_rotate(z.parent.parent)
			else:
				y = z.parent.parent.left
				if y.color == "red":
					z.parent.color = "black"
					y.color = "black"
					z.parent.parent.color = "red"
					z = z.parent.parent
				elif z == z.parent.left:
					z = z.parent
					self.right_rotate(z)
				else:
					z.parent.color = "black"
					z.parent.parent.color = "red"
					self.left_rotate(z.parent.parent)
		self.root.color = "black"

	def rb_min(self, tree):
		while tree.left.key != None:  
			tree = tree.left
		return tree

	def rb_max(self, tree):
		while tree.right.key != None:
			tree = tree.right
		return tree


	def rb_transplant(self, u, v):
		if u.parent == self.nil:
			self.root = v
		elif u == u.parent.left:
			u.parent.left = v
		else:
			u.parent.right = v
		v.parent = u.parent


	def rb_delete(self, z):
		y = z
		y_original_color = y.color
		if z.left == self.nil:
			x = z.right
			self.rb_transplant(z, z.right)
		elif z.right == self.nil:
			x = z.left
			self.rb_transplant(z, z.left)
		else:
			y = self.rb_min(z.right) 
			y_original_color = y.color
			x = y.right
			if y.parent == z:
				x.parent = y
			else:
				self.rb_transplant(y, y.right)
				y.right = z.right
				y.right.parent = y
			self.rb_transplant(z, y)
			y.left = z.left
			y.left.parent = y
			y.color = z.color
		if y_original_color == "black":
			self.rb_delete_fixup(x)

	def rb_delete_fixup(self, x):
		while x != self.root and x.color == "black":
			if x == x.parent.left:
				w = x.parent.right
				if w.color == "red":
					w.color = "black"
					x.parent.color = "red"
					self.left_rotate(x.parent)
					w = x.parent.right
				if w.left.color == "black" and w.right.color == "black":
					w.color = "red"
					x = x.parent
				else:
					if w.right.color == "black":
						w.left.color = "black"
						w.color = "red"
						self.right_rotate(w)
						w = x.parent.right
					w.color = x.parent.color
					x.parent.color = "black"
					w.right.color = "black"
					self.left_rotate(x.parent)
					x = self.root
			else:
				w = x.parent.left
				if w.color == "red":
					w.color = "black"
					x.parent.color = "red"
					self.right_rotate(x.parent)
					w = x.parent.left
				if w.right.color == "black" and w.left.color == "black":
					w.color = "red"
					x = x.parent
				else:
					if w.left.color == "black":
						w.right.color == "black"
						w.color = "red"
						self.left_rotate(w)
						w = x.parent.left		
					w.color = x.parent.color
					x.parent.color = "black"
					w.left.color = "black"
					self.right_rotate(x.parent)
					x = self.root
		x.color = "black"



	def search(self, tree, k):
		if tree.key == None or k == tree.key:
			return tree
		if k < tree.key:
			return self.search(tree.left, k)
		else:
			return self.search(tree.right, k)



	inorder_result = [ ]
	blacknode = [ ]

	def inorder(self,tree):
		if tree is None:
			return
		else:
			self.inorder(tree.left)
			if tree.color is "black":
				rb_tree.blacknode.append(tree.key)
			rb_tree.inorder_result.append(tree.key)
			self.inorder(tree.right)
		

	def print(self,tree,level):
	    if tree.right is not None:
	        self.print(tree.right,level + 1)
	    for i in range(level):
	        print('   	', end='')
	    print((tree.key, tree.color))
	    if tree.left is not None:
	        self.print(tree.left, level + 1)

	def rb_bh(self):
		x = self.root
		bh = 0
		while x is not self.nil:
			if x.color is "black":
				bh = bh + 1
			x = x.right
		return bh

# %%
import time
import numpy as np

NUM = 1000

for i in range(10):
    t = rb_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  0.0039899349212646484
# 1 번째 트리 높이:  6
# 1 - 1 번째 탐색, 찾는 숫자 9223291 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 8421409 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 3363074 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 3331530 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 4414314 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  0.003989219665527344
# 2 번째 트리 높이:  6
# 2 - 1 번째 탐색, 찾는 숫자 1246541 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 9398975 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 2228147 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 2811464 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 9903596 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  0.00498509407043457
# 3 번째 트리 높이:  6
# 3 - 1 번째 탐색, 찾는 숫자 1765265 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 8077222 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 676391 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 996811 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 8933155 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  0.002991914749145508
# 4 번째 트리 높이:  6
# 4 - 1 번째 탐색, 찾는 숫자 4674443 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 9268691 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 34208 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 7617028 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 5931235 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  0.002991914749145508
# 5 번째 트리 높이:  7
# 5 - 1 번째 탐색, 찾는 숫자 9371213 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 1899567 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 2155900 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 8860548 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 4613856 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  0.002991199493408203
# 6 번째 트리 높이:  6
# 6 - 1 번째 탐색, 찾는 숫자 473368 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 8389636 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 9451468 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 992538 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 6362933 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  0.003989219665527344
# 7 번째 트리 높이:  6
# 7 - 1 번째 탐색, 찾는 숫자 1467350 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 871953 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 9566004 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 7532725 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 3153628 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  0.001039266586303711
# 8 번째 트리 높이:  6
# 8 - 1 번째 탐색, 찾는 숫자 6659875 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 69919 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 7384125 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 6554238 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 4099172 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  0.0
# 9 번째 트리 높이:  6
# 9 - 1 번째 탐색, 찾는 숫자 6644370 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 5513044 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 9005822 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 1569917 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 7723807 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  0.0
# 10 번째 트리 높이:  6
# 10 - 1 번째 탐색, 찾는 숫자 5076255 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 1808493 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 5435891 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 4553913 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 8115788 탐색+삭제 시간: 0.0

# %%
import time
import numpy as np

NUM = 10000

for i in range(10):
    t = rb_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  0.04989218711853027
# 1 번째 트리 높이:  9
# 1 - 1 번째 탐색, 찾는 숫자 2126700 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 1988770 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 1012432 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 4914667 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 1794265 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  0.036580801010131836
# 2 번째 트리 높이:  8
# 2 - 1 번째 탐색, 찾는 숫자 6316581 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 3885273 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 878805 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 7668093 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 5071998 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  0.04684162139892578
# 3 번째 트리 높이:  8
# 3 - 1 번째 탐색, 찾는 숫자 8448483 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 9187381 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 3177878 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 1815144 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 1377706 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  0.04686594009399414
# 4 번째 트리 높이:  8
# 4 - 1 번째 탐색, 찾는 숫자 557640 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 1899757 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 197200 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 6641606 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 5580094 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  0.032639265060424805
# 5 번째 트리 높이:  9
# 5 - 1 번째 탐색, 찾는 숫자 627839 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 7097014 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 4605861 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 3637533 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 9360940 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  0.04687809944152832
# 6 번째 트리 높이:  8
# 6 - 1 번째 탐색, 찾는 숫자 4924857 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 9248932 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 8202200 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 5587298 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 1520382 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  0.04686546325683594
# 7 번째 트리 높이:  8
# 7 - 1 번째 탐색, 찾는 숫자 5985903 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 3953036 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 7565176 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 4044991 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 2905523 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  0.04686307907104492
# 8 번째 트리 높이:  9
# 8 - 1 번째 탐색, 찾는 숫자 9386273 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 5912280 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 1756944 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 2933132 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 863565 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  0.03128552436828613
# 9 번째 트리 높이:  8
# 9 - 1 번째 탐색, 찾는 숫자 476863 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 8588392 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 9237033 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 6145221 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 7820580 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  0.06283283233642578
# 10 번째 트리 높이:  8
# 10 - 1 번째 탐색, 찾는 숫자 5889699 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 8187111 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 9278993 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 3551760 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 8761409 탐색+삭제 시간: 0.0

# %%
import time
import numpy as np


NUM = 100000

for i in range(10):
    t = rb_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  3.556776523590088
# 1 번째 트리 높이:  10
# 1 - 1 번째 탐색, 찾는 숫자 6876638 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 3621410 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 8016856 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 5351825 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 7495244 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  0.8649661540985107
# 2 번째 트리 높이:  10
# 2 - 1 번째 탐색, 찾는 숫자 8987381 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 4564408 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 7930147 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 3746997 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 4319179 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  0.8610303401947021
# 3 번째 트리 높이:  11
# 3 - 1 번째 탐색, 찾는 숫자 6881063 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 7312659 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 4209468 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 5141695 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 1912428 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  0.7885138988494873
# 4 번째 트리 높이:  10
# 4 - 1 번째 탐색, 찾는 숫자 9042624 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 4188927 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 2617143 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 67146 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 2931478 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  0.8933978080749512
# 5 번째 트리 높이:  10
# 5 - 1 번째 탐색, 찾는 숫자 7702335 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 6898989 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 7180491 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 5831857 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 1364467 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  0.9171195030212402
# 6 번째 트리 높이:  10
# 6 - 1 번째 탐색, 찾는 숫자 5256187 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 5878984 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 446213 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 2691360 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 9238553 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  0.8966624736785889
# 7 번째 트리 높이:  10
# 7 - 1 번째 탐색, 찾는 숫자 9590283 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 7942107 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 4719652 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 5975810 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 3551197 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  0.8944225311279297
# 8 번째 트리 높이:  10
# 8 - 1 번째 탐색, 찾는 숫자 758192 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 5236961 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 4724185 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 8776331 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 8559477 탐색+삭제 시간: 0.0
#
# 9 번째 트리 생성 시간:  0.8465368747711182
# 9 번째 트리 높이:  10
# 9 - 1 번째 탐색, 찾는 숫자 6539006 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 2776117 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 4640802 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 7154216 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 6383337 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  0.8340198993682861
# 10 번째 트리 높이:  10
# 10 - 1 번째 탐색, 찾는 숫자 3419378 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 8401885 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 8521533 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 5386346 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 4953902 탐색+삭제 시간: 0.0

# %%
import time
import numpy as np

NUM = 1000000

for i in range(10):
    t = rb_tree()
    f = open(str(NUM)+"_"+str(i)+".txt",'r')
    nums = []
    lines = f.readlines()
    for line in lines:
        nums.append(int(line))

    start = time.time()
    for num in nums:
        t.rb_insert(Node(num))
    print(i+1,"번째 트리 생성 시간: ",time.time() - start)
    print(i+1,"번째 트리 높이: ",t.rb_bh())
    
    for j in range(5):
        start = time.time()
        randNum = nums[np.random.randint(NUM)]
        t.rb_delete(t.search(t.get_root(),randNum))
        print(i+1,"-",j+1,"번째 탐색, 찾는 숫자",randNum,"탐색+삭제 시간:",time.time() - start)
    
    print()
    
    f.close()
# Out:
# 1 번째 트리 생성 시간:  14.107460737228394
# 1 번째 트리 높이:  12
# 1 - 1 번째 탐색, 찾는 숫자 1826204 탐색+삭제 시간: 0.0
# 1 - 2 번째 탐색, 찾는 숫자 7621983 탐색+삭제 시간: 0.0
# 1 - 3 번째 탐색, 찾는 숫자 7643003 탐색+삭제 시간: 0.0
# 1 - 4 번째 탐색, 찾는 숫자 5488405 탐색+삭제 시간: 0.0
# 1 - 5 번째 탐색, 찾는 숫자 7816425 탐색+삭제 시간: 0.0
#
# 2 번째 트리 생성 시간:  15.30591630935669
# 2 번째 트리 높이:  12
# 2 - 1 번째 탐색, 찾는 숫자 1173127 탐색+삭제 시간: 0.0
# 2 - 2 번째 탐색, 찾는 숫자 8813845 탐색+삭제 시간: 0.0
# 2 - 3 번째 탐색, 찾는 숫자 5994617 탐색+삭제 시간: 0.0
# 2 - 4 번째 탐색, 찾는 숫자 8026091 탐색+삭제 시간: 0.0
# 2 - 5 번째 탐색, 찾는 숫자 2773358 탐색+삭제 시간: 0.0
#
# 3 번째 트리 생성 시간:  16.25875735282898
# 3 번째 트리 높이:  12
# 3 - 1 번째 탐색, 찾는 숫자 9500031 탐색+삭제 시간: 0.0
# 3 - 2 번째 탐색, 찾는 숫자 8395016 탐색+삭제 시간: 0.0
# 3 - 3 번째 탐색, 찾는 숫자 6610001 탐색+삭제 시간: 0.0
# 3 - 4 번째 탐색, 찾는 숫자 9842031 탐색+삭제 시간: 0.0
# 3 - 5 번째 탐색, 찾는 숫자 7816035 탐색+삭제 시간: 0.0
#
# 4 번째 트리 생성 시간:  15.61873173713684
# 4 번째 트리 높이:  12
# 4 - 1 번째 탐색, 찾는 숫자 8427388 탐색+삭제 시간: 0.0
# 4 - 2 번째 탐색, 찾는 숫자 1957326 탐색+삭제 시간: 0.0
# 4 - 3 번째 탐색, 찾는 숫자 1730230 탐색+삭제 시간: 0.0
# 4 - 4 번째 탐색, 찾는 숫자 5375698 탐색+삭제 시간: 0.0
# 4 - 5 번째 탐색, 찾는 숫자 6893472 탐색+삭제 시간: 0.0
#
# 5 번째 트리 생성 시간:  15.760961055755615
# 5 번째 트리 높이:  12
# 5 - 1 번째 탐색, 찾는 숫자 53335 탐색+삭제 시간: 0.0
# 5 - 2 번째 탐색, 찾는 숫자 604211 탐색+삭제 시간: 0.0
# 5 - 3 번째 탐색, 찾는 숫자 6394902 탐색+삭제 시간: 0.0
# 5 - 4 번째 탐색, 찾는 숫자 4055304 탐색+삭제 시간: 0.0
# 5 - 5 번째 탐색, 찾는 숫자 652264 탐색+삭제 시간: 0.0
#
# 6 번째 트리 생성 시간:  17.183796644210815
# 6 번째 트리 높이:  12
# 6 - 1 번째 탐색, 찾는 숫자 6766141 탐색+삭제 시간: 0.0
# 6 - 2 번째 탐색, 찾는 숫자 7096464 탐색+삭제 시간: 0.0
# 6 - 3 번째 탐색, 찾는 숫자 176371 탐색+삭제 시간: 0.0
# 6 - 4 번째 탐색, 찾는 숫자 7491659 탐색+삭제 시간: 0.0
# 6 - 5 번째 탐색, 찾는 숫자 9667141 탐색+삭제 시간: 0.0
#
# 7 번째 트리 생성 시간:  15.440490484237671
# 7 번째 트리 높이:  13
# 7 - 1 번째 탐색, 찾는 숫자 6776578 탐색+삭제 시간: 0.0
# 7 - 2 번째 탐색, 찾는 숫자 1500413 탐색+삭제 시간: 0.0
# 7 - 3 번째 탐색, 찾는 숫자 3169579 탐색+삭제 시간: 0.0
# 7 - 4 번째 탐색, 찾는 숫자 6087940 탐색+삭제 시간: 0.0
# 7 - 5 번째 탐색, 찾는 숫자 4751988 탐색+삭제 시간: 0.0
#
# 8 번째 트리 생성 시간:  17.383822202682495
# 8 번째 트리 높이:  13
# 8 - 1 번째 탐색, 찾는 숫자 2505030 탐색+삭제 시간: 0.0
# 8 - 2 번째 탐색, 찾는 숫자 5572211 탐색+삭제 시간: 0.0
# 8 - 3 번째 탐색, 찾는 숫자 557797 탐색+삭제 시간: 0.0
# 8 - 4 번째 탐색, 찾는 숫자 5968774 탐색+삭제 시간: 0.0
# 8 - 5 번째 탐색, 찾는 숫자 4058742 탐색+삭제 시간: 0.015574216842651367
#
# 9 번째 트리 생성 시간:  16.33155918121338
# 9 번째 트리 높이:  12
# 9 - 1 번째 탐색, 찾는 숫자 8816577 탐색+삭제 시간: 0.0
# 9 - 2 번째 탐색, 찾는 숫자 3706637 탐색+삭제 시간: 0.0
# 9 - 3 번째 탐색, 찾는 숫자 2271502 탐색+삭제 시간: 0.0
# 9 - 4 번째 탐색, 찾는 숫자 5576652 탐색+삭제 시간: 0.0
# 9 - 5 번째 탐색, 찾는 숫자 3879108 탐색+삭제 시간: 0.0
#
# 10 번째 트리 생성 시간:  16.55569076538086
# 10 번째 트리 높이:  12
# 10 - 1 번째 탐색, 찾는 숫자 4925614 탐색+삭제 시간: 0.0
# 10 - 2 번째 탐색, 찾는 숫자 3641744 탐색+삭제 시간: 0.0
# 10 - 3 번째 탐색, 찾는 숫자 596091 탐색+삭제 시간: 0.0
# 10 - 4 번째 탐색, 찾는 숫자 6949228 탐색+삭제 시간: 0.0
# 10 - 5 번째 탐색, 찾는 숫자 2457134 탐색+삭제 시간: 0.0
